# %%
# Import dependencies
from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd
import time

# %%
# Initialize Splinter browser
browser = Browser('chrome')

# URLs for Honda CR-V and CR-V Hybrid
base_urls = [
    'https://www.cars.com/shopping/results/?makes[]=honda&maximum_distance=50&models[]=honda-cr_v&page=1&page_size=100&stock_type=all&zip=61606',
    'https://www.cars.com/shopping/results/?stock_type=all&makes%5B%5D=honda&models%5B%5D=honda-cr_v_hybrid&maximum_distance=50&zip=61606'
]

# Create empty lists to store data
models = []
mileages=[]
statuses = []
prices = []
dealers = []
cities = []

# Function to reset lists
def clear_lists():
    global models, statuses, prices, dealers, cities, mileages
    models = []
    statuses = []
    prices = []
    dealers = []
    cities = []
    mileages = []

# Function to scrape data from a given URL
def scrape_url(url):
    browser.visit(url)
    html = browser.html
    car_soup = soup(html, 'html.parser')
    car_list = car_soup.find_all('div', class_='vehicle-card')
    
    for car in car_list:
        # Extract car model
        car_model = car.find('h2', class_='title')
        model = str(car_model.get_text(strip=True)) if car_model else 'N/A'

        # Extract car mileage
        car_mileage = car.find('div', class_='mileage')
        mileage = str(car_mileage.get_text(strip=True)) if car_mileage else 'N/A'

        # Extract car status
        car_status = car.find('p', class_='stock-type')
        status = str(car_status.get_text(strip=True)) if car_status else 'N/A'

        # Extract car price
        car_price = car.find('span', class_='primary-price')
        price = str(car_price.get_text(strip=True)) if car_price else 'N/A'

        # Extract dealer name
        car_dealer = car.find('div', class_='dealer-name').find('strong')
        dealer = str(car_dealer.get_text(strip=True)) if car_dealer else 'N/A'

        # Extract dealer city
        dealer_city = car.find('div', class_='miles-from')
        city = str(dealer_city.get_text(strip=True)) if dealer_city else 'N/A'

        # Append details to lists
        models.append(model)
        mileages.append(mileage)
        statuses.append(status)
        prices.append(price)
        dealers.append(dealer)
        cities.append(city)

# Scrape data from each URL in the base_urls list
for url in base_urls:
    scrape_url(url)

# %%
# Create df
data={
    'Model': models,
    'Status': statuses,
    'Price (USD)': prices,
    'Dealer': dealers,
    'City': cities,
    'Mileage (mi)': mileages,
    }
car_df= pd.DataFrame(data)

# %%
# Close the browser
browser.quit()

# %%
# Clear lists after scraping
# clear_lists()

# %%
# Display DF
print("Original DataFrame:")
print(car_df)
print()
# Out:
# Original DataFrame:
#                              Model           Status Price (USD)  \
# 0             2017 Honda CR-V EX-L             Used     $16,066
# 1             2013 Honda CR-V EX-L             Used     $13,995
# 2             2025 Honda CR-V EX-L              New     $37,850
# 3             2023 Honda CR-V EX-L             Used     $31,998
# 4             2024 Honda CR-V EX-L             Used     $34,998
# ..                             ...              ...         ...
# 77  2021 Honda CR-V Hybrid Touring  Honda Certified     $32,982
# 78  2024 Honda CR-V Hybrid Sport-L             Used     $37,999
# 79    2024 Honda CR-V Hybrid Sport             Used     $34,500
# 80       2020 Honda CR-V Hybrid EX             Used     $22,993
# 81    2023 Honda CR-V Hybrid Sport             Used     $32,600
#
#                                                Dealer  \
# 0                            Yemm Chevrolet Buick GMC
# 1                           Auto House of Bloomington
# 2                        O'Brien Honda of Bloomington
# 3   CarMax Austin North - Offering Express Pickup ...
# 4   CarMax Austin North - Offering Express Pickup ...
# ..                                                ...
# 77                                        Bosak Honda
# 78                                     Honda of Lisle
# 79                           Gerald Honda of Matteson
# 80                       McGrath Honda of St. Charles
# 81                                     Bill Kay Honda
#
#                          City Mileage (mi)
# 0      Galesburg, IL (45 mi.)  173,049 mi.
# 1    Bloomington, IL (38 mi.)   93,804 mi.
# 2    Bloomington, IL (38 mi.)          N/A
# 3                         N/A   21,648 mi.
# 4                         N/A    6,753 mi.
# ..                        ...          ...
# 77     Highland, IN (126 mi.)   29,576 mi.
# 78        Lisle, IL (111 mi.)    4,302 mi.
# 79     Matteson, IL (112 mi.)      329 mi.
# 80  St. Charles, IL (110 mi.)   64,669 mi.
# 81   Bourbonnais, IL (98 mi.)    9,471 mi.
#
# [82 rows x 6 columns]

# %%
# Check for missing values:
missing_values= car_df.isnull().sum()
print("Missing values:")
print(missing_values)
print()
# Out:
# Missing values:
# Model           0
# Status          0
# Price (USD)     0
# Dealer          0
# City            0
# Mileage (mi)    0
# dtype: int64

# %%
# Split 'Model' column into 'Year', 'Manufacturer', 'Model', and 'Trim'
# Handling 'CR-V' and 'CR-V Hybrid' correctly
split_df = car_df['Model'].str.extract(r'(?P<Year>\d{4})\s+(?P<Manufacturer>[\w-]+)\s+(?P<Model>CR-V(?:\s+Hybrid)?)\s+(?P<Trim>.*)')
#  Captures group called 'Year' (?P<Year> ; \d{4} matches to 4 digits
# Matches 1+ whitespace characters to account for space between Year and Manufacturer \s+
# Captures another group called Manufacturer, matches by 1+ words (?P<Manufacturer>[\w-]+)
# Captures group called Model (?P<Model> ; CR-V(?:\s+Hybrid)?) Matches to string "CR-V" 
# or by a white space (?:\s) plus the string "Hybrid" +Hybrid)?)
# Captures group called Trim (?P<Trim>) ; Matches any character 0+ times 
# (i.e. captures everything after Model as the Trim) using .*

# Replace 'Not Priced' with NaN and convert 'Price' column to numeric
car_df['Price (USD)'] = pd.to_numeric(car_df['Price (USD)'].replace('Not Priced', pd.NA).str.replace('[\$,]', '', regex=True), errors='coerce')

# Clean the 'Mileage' column
car_df['Mileage (mi)'] = pd.to_numeric(car_df['Mileage (mi)'].str.replace('mi.', '').str.replace(',', '').str.strip(), errors='coerce')

# Concatenate split_df with the remaining columns from car_df
car_df = pd.concat([split_df, car_df[['Status', 'Price (USD)', 'Dealer', 'City', 'Mileage (mi)']]], axis=1)

# Reorder columns as required
car_df = car_df[['Year', 'Manufacturer', 'Model', 'Trim', 'Mileage (mi)', 'Status', 'Price (USD)', 'Dealer', 'City']]

# Display the updated DataFrame
print("Final DataFrame:")
print(car_df)
# Out:
# Final DataFrame:
#     Year Manufacturer        Model     Trim  Mileage (mi)           Status  \
# 0   2017        Honda         CR-V     EX-L      173049.0             Used
# 1   2013        Honda         CR-V     EX-L       93804.0             Used
# 2   2025        Honda         CR-V     EX-L           NaN              New
# 3   2023        Honda         CR-V     EX-L       21648.0             Used
# 4   2024        Honda         CR-V     EX-L        6753.0             Used
# ..   ...          ...          ...      ...           ...              ...
# 77  2021        Honda  CR-V Hybrid  Touring       29576.0  Honda Certified
# 78  2024        Honda  CR-V Hybrid  Sport-L        4302.0             Used
# 79  2024        Honda  CR-V Hybrid    Sport         329.0             Used
# 80  2020        Honda  CR-V Hybrid       EX       64669.0             Used
# 81  2023        Honda  CR-V Hybrid    Sport        9471.0             Used
#
#     Price (USD)                                             Dealer  \
# 0         16066                           Yemm Chevrolet Buick GMC
# 1         13995                          Auto House of Bloomington
# 2         37850                       O'Brien Honda of Bloomington
# 3         31998  CarMax Austin North - Offering Express Pickup ...
# 4         34998  CarMax Austin North - Offering Express Pickup ...
# ..          ...                                                ...
# 77        32982                                        Bosak Honda
# 78        37999                                     Honda of Lisle
# 79        34500                           Gerald Honda of Matteson
# 80        22993                       McGrath Honda of St. Charles
# 81        32600                                     Bill Kay Honda
#
#                          City
# 0      Galesburg, IL (45 mi.)
# 1    Bloomington, IL (38 mi.)
# 2    Bloomington, IL (38 mi.)
# 3                         N/A
# 4                         N/A
# ..                        ...
# 77     Highland, IN (126 mi.)
# 78        Lisle, IL (111 mi.)
# 79     Matteson, IL (112 mi.)
# 80  St. Charles, IL (110 mi.)
# 81   Bourbonnais, IL (98 mi.)
#
# [82 rows x 9 columns]
# C:\Users\awsom\AppData\Local\Temp\ipykernel_6520\3172368673.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_df['Mileage (mi)'] = pd.to_numeric(car_df['Mileage (mi)'].str.replace('mi.', '').str.replace(',', '').str.strip(), errors='coerce')

# %%
car_df
# Out:
#     Year Manufacturer        Model     Trim  Mileage (mi)           Status  \
# 0   2017        Honda         CR-V     EX-L      173049.0             Used
# 1   2013        Honda         CR-V     EX-L       93804.0             Used
# 2   2025        Honda         CR-V     EX-L           NaN              New
# 3   2023        Honda         CR-V     EX-L       21648.0             Used
# 4   2024        Honda         CR-V     EX-L        6753.0             Used
# ..   ...          ...          ...      ...           ...              ...
# 77  2021        Honda  CR-V Hybrid  Touring       29576.0  Honda Certified
# 78  2024        Honda  CR-V Hybrid  Sport-L        4302.0             Used
# 79  2024        Honda  CR-V Hybrid    Sport         329.0             Used
# 80  2020        Honda  CR-V Hybrid       EX       64669.0             Used
# 81  2023        Honda  CR-V Hybrid    Sport        9471.0             Used
#
#     Price (USD)                                             Dealer  \
# 0         16066                           Yemm Chevrolet Buick GMC
# 1         13995                          Auto House of Bloomington
# 2         37850                       O'Brien Honda of Bloomington
# 3         31998  CarMax Austin North - Offering Express Pickup ...
# 4         34998  CarMax Austin North - Offering Express Pickup ...
# ..          ...                                                ...
# 77        32982                                        Bosak Honda
# 78        37999                                     Honda of Lisle
# 79        34500                           Gerald Honda of Matteson
# 80        22993                       McGrath Honda of St. Charles
# 81        32600                                     Bill Kay Honda
#
#                          City
# 0      Galesburg, IL (45 mi.)
# 1    Bloomington, IL (38 mi.)
# 2    Bloomington, IL (38 mi.)
# 3                         N/A
# 4                         N/A
# ..                        ...
# 77     Highland, IN (126 mi.)
# 78        Lisle, IL (111 mi.)
# 79     Matteson, IL (112 mi.)
# 80  St. Charles, IL (110 mi.)
# 81   Bourbonnais, IL (98 mi.)
#
# [82 rows x 9 columns]

# %%
print(car_df.to_string())
# Out:
#     Year Manufacturer        Model           Trim  Mileage (mi)           Status  Price (USD)                                                           Dealer                           City
# 0   2017        Honda         CR-V           EX-L      173049.0             Used        16066                                         Yemm Chevrolet Buick GMC         Galesburg, IL (45 mi.)
# 1   2013        Honda         CR-V           EX-L       93804.0             Used        13995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 2   2025        Honda         CR-V           EX-L           NaN              New        37850                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 3   2023        Honda         CR-V           EX-L       21648.0             Used        31998  CarMax Austin North - Offering Express Pickup and Home Delivery                            N/A
# 4   2024        Honda         CR-V           EX-L        6753.0             Used        34998  CarMax Austin North - Offering Express Pickup and Home Delivery                            N/A
# 5   2018        Honda         CR-V           EX-L       45437.0             Used        24998  CarMax Indianapolis - Offering Express Pickup and Home Delivery                            N/A
# 6   2022        Honda         CR-V           EX-L       23051.0             Used        30998  CarMax Indianapolis - Offering Express Pickup and Home Delivery                            N/A
# 7   2019        Honda         CR-V        Touring       37502.0             Used        28000                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 8   2014        Honda         CR-V           EX-L       38412.0             Used        19998   CarMax Gainesville - Offering Express Pickup and Home Delivery                            N/A
# 9   2018        Honda         CR-V             EX       70211.0             Used        21900                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 10  2014        Honda         CR-V             LX      115438.0             Used        14998           CarMax LAX - Offering Express Pickup and Home Delivery                            N/A
# 11  2024        Honda         CR-V       EX-L 2WD           NaN              New        36465                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 12  2024        Honda  CR-V Hybrid  Sport Touring           NaN              New        41550                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 13  2021        Honda         CR-V             EX       22594.0             Used        28998  CarMax Indianapolis - Offering Express Pickup and Home Delivery                            N/A
# 14  2025        Honda         CR-V           EX-L           NaN              New        36805                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 15  2008        Honda         CR-V             EX      163345.0             Used         6995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 16  2019        Honda         CR-V             EX       55612.0             Used        23998  CarMax Indianapolis - Offering Express Pickup and Home Delivery                            N/A
# 17  2013        Honda         CR-V           EX-L      119882.0             Used        11495                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 18  2019        Honda         CR-V             EX       30736.0             Used        26998        CarMax Newark - Offering Express Pickup and Home Delivery                            N/A
# 19  2014        Honda         CR-V             LX       99396.0             Used        13295                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 20  2013        Honda         CR-V             EX      107368.0             Used        13995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 21  2015        Honda         CR-V             EX       90328.0             Used        16495                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 22  2016        Honda         CR-V             SE       99387.0             Used        15995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 23  2014        Honda         CR-V           EX-L       99927.0             Used        14995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 24  2015        Honda         CR-V             LX      137738.0             Used        11995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 25  2015        Honda         CR-V             EX      141303.0             Used        13500                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 26  2025        Honda         CR-V             LX           NaN              New        32950                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 27  2025        Honda         CR-V           EX-L           NaN              New        38305                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 28  2016        Honda         CR-V        Touring       95621.0             Used        17000                                                    Peoria Toyota             Peoria, IL (6 mi.)
# 29  2019        Honda         CR-V             LX       76605.0             Used        20500                       Sam Leman Dodge Chrysler Jeep RAM - Peoria             Peoria, IL (6 mi.)
# 30  2020        Honda         CR-V        Touring       31462.0             Used        28986                                                  Green Chevrolet             Peoria, IL (6 mi.)
# 31  2023        Honda         CR-V       EX-L AWD       14808.0  Honda Certified        34500                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 32  2013        Honda         CR-V           EX-L      166892.0             Used        10495                                          Twin City Auto Mall Inc       Bloomington, IL (37 mi.)
# 33  2023        Honda         CR-V           EX-L       19364.0             Used        32250                                             Barker Motor Company       Bloomington, IL (38 mi.)
# 34  2017        Honda         CR-V           EX-L      154429.0             Used        15500                                        O'Brien Hyundai of Normal            Normal, IL (37 mi.)
# 35  2014        Honda         CR-V             EX      118779.0             Used        13836                  Sam Leman Dodge Chrysler Jeep RAM Fiat - Morton            Morton, IL (10 mi.)
# 36  2017        Honda         CR-V           EX-L       31665.0             Used        23998  CarMax Austin North - Offering Express Pickup and Home Delivery                            N/A
# 37  2015        Honda         CR-V           EX-L       95877.0             Used        17250                       Sam Leman Dodge Chrysler Jeep RAM - Peoria             Peoria, IL (6 mi.)
# 38  2008        Honda         CR-V             EX      126787.0             Used         9995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 39  2020        Honda         CR-V             EX       61537.0             Used        22998                                           Ray Dennison Chevrolet              Pekin, IL (8 mi.)
# 40  2017        Honda         CR-V        Touring      118548.0             Used        18462                                                      Heller Ford           El Paso, IL (31 mi.)
# 41  2021        Honda         CR-V             EX       30819.0             Used        26998   CarMax Bloomington - Offering Express Pickup and Home Delivery       Bloomington, IL (38 mi.)
# 42  2010        Honda         CR-V           EX-L      157077.0             Used         9995                                         Crossroads Used Cars LLC           Tremont, IL (14 mi.)
# 43  2018        Honda         CR-V           EX-L       93337.0             Used        21682                                                  Sam Leman Mazda       Bloomington, IL (38 mi.)
# 44  2024        Honda  CR-V Hybrid        Sport-L        6840.0             Used        37495                                               Leman's Chevy City       Bloomington, IL (38 mi.)
# 45  2019        Honda         CR-V        Touring      100074.0             Used        22750                                   Sam Leman Toyota - Bloomington       Bloomington, IL (38 mi.)
# 46  2018        Honda         CR-V           EX-L       78958.0             Used        21995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 47  2017        Honda         CR-V           EX-L       99241.0             Used        20995                                                 Mike Murphy Ford            Morton, IL (10 mi.)
# 48  2018        Honda         CR-V             EX       93403.0             Used        20495                       Sam Leman Dodge Chrysler Jeep RAM - Peoria             Peoria, IL (6 mi.)
# 49  2018        Honda         CR-V        Touring      110392.0             Used        21446                                           Jim Xamis Ford Lincoln           Lincoln, IL (40 mi.)
# 50  2014        Honda         CR-V           EX-L      159604.0             Used        13000                                           Fort's Toyota of Pekin        North Pekin, IL (6 mi.)
# 51  2009        Honda         CR-V             LX      108113.0             Used         9995                                        Auto House of Bloomington       Bloomington, IL (38 mi.)
# 52  2013        Honda         CR-V           EX-L      169890.0             Used        12500                                           Fort's Toyota of Pekin        North Pekin, IL (6 mi.)
# 53  2013        Honda         CR-V           EX-L      172564.0             Used        11425                                                  Lexus of Peoria             Peoria, IL (6 mi.)
# 54  2018        Honda         CR-V             EX       83088.0             Used        20500                                                    Peoria Toyota             Peoria, IL (6 mi.)
# 55  2018        Honda         CR-V        Touring       47677.0             Used        25950                                                Bob Lindsay Acura             Peoria, IL (6 mi.)
# 56  2017        Honda         CR-V             EX       96489.0             Used        17900                                                Bob Lindsay Acura             Peoria, IL (6 mi.)
# 57   NaN          NaN          NaN            NaN           1.0  Honda Certified        20952                                                Bob Lindsay Honda             Peoria, IL (6 mi.)
# 58  2021        Honda         CR-V         AWD EX       25930.0             Used        27200                                     O'Brien Honda of Bloomington       Bloomington, IL (38 mi.)
# 59  2021        Honda         CR-V             EX       31948.0             Used        24998                                         Shottenkirk Fort Madison      Fort Madison, IA (93 mi.)
# 60  2020        Honda         CR-V             EX       60030.0             Used        24000                                   Clement Pre-Owned (Florissant)       Florissant, MO (137 mi.)
# 61  2018        Honda         CR-V           EX-L       62994.0             Used        22494                                                   Owen Ford (IL)         Marshall, IL (136 mi.)
# 62  2015        Honda         CR-V           EX-L      155201.0             Used        12250                             Larry Roesch Dodge Chrysler Jeep RAM         Elmhurst, IL (122 mi.)
# 63  2018        Honda         CR-V           EX-L       60961.0             Used        22995                                            Chevrolet of Homewood         Homewood, IL (119 mi.)
# 64  2022        Honda         CR-V         AWD EX        6610.0             Used        28640                                 Zeigler Buick GMC of Lincolnwood      Lincolnwood, IL (134 mi.)
# 65  2016        Honda         CR-V             SE      110162.0             Used        15895                                       DriveTime of South Chicago       Midlothian, IL (117 mi.)
# 66  2020        Honda         CR-V           EX-L       32707.0             Used        27990                                                MINI of St. Louis        St. Louis, MO (150 mi.)
# 67  2021        Honda         CR-V           EX-L       78711.0             Used        26500                                   Clement Pre-Owned (Florissant)       Florissant, MO (137 mi.)
# 68  2017        Honda         CR-V           EX-L       39861.0             Used        22750                                         Rizza Cadillac Buick GMC      Tinley Park, IL (112 mi.)
# 69  2023        Honda  CR-V Hybrid  Sport Touring        9888.0             Used        38998  CarMax Indianapolis - Offering Express Pickup and Home Delivery                            N/A
# 70  2023        Honda  CR-V Hybrid  Sport Touring       13757.0             Used        39998  CarMax Indianapolis - Offering Express Pickup and Home Delivery                            N/A
# 71  2023        Honda  CR-V Hybrid  Sport Touring        3450.0             Used        39995                                  Uftring Chevrolet in Washington         Washington, IL (9 mi.)
# 72  2023        Honda  CR-V Hybrid  Sport Touring        6518.0  Honda Certified        40994                                                     Muller Honda    Highland Park, IL (138 mi.)
# 73  2022        Honda  CR-V Hybrid           EX-L       31314.0             Used        31899                                      INFINITI of Clarendon Hills  Clarendon Hills, IL (115 mi.)
# 74  2022        Honda  CR-V Hybrid             EX       39361.0             Used        27400                                     Ed Napleton Honda St. Peters     Saint Peters, MO (142 mi.)
# 75  2024        Honda  CR-V Hybrid          Sport        2187.0             Used        34955                                         Gerald Honda of Matteson         Matteson, IL (112 mi.)
# 76  2021        Honda  CR-V Hybrid             EX       57509.0             Used        26062                                                 Bill Walsh Honda            Ottawa, IL (62 mi.)
# 77  2021        Honda  CR-V Hybrid        Touring       29576.0  Honda Certified        32982                                                      Bosak Honda         Highland, IN (126 mi.)
# 78  2024        Honda  CR-V Hybrid        Sport-L        4302.0             Used        37999                                                   Honda of Lisle            Lisle, IL (111 mi.)
# 79  2024        Honda  CR-V Hybrid          Sport         329.0             Used        34500                                         Gerald Honda of Matteson         Matteson, IL (112 mi.)
# 80  2020        Honda  CR-V Hybrid             EX       64669.0             Used        22993                                     McGrath Honda of St. Charles      St. Charles, IL (110 mi.)
# 81  2023        Honda  CR-V Hybrid          Sport        9471.0             Used        32600                                                   Bill Kay Honda       Bourbonnais, IL (98 mi.)

# %%
car_df.to_excel("CR-V.xlsx")
